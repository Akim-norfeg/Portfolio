# %% [markdown]
# # Построение дашбордов в Tableau

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# TED (аббревиатура от Technology, Education, Design — «технологии, образование, дизайн») — это некоммерческая организация, организующая популярные конференции, на которых эксперты из различных сфер делятся лекциями на актуальные социальные, культурные и научные темы
#
# Среди участников TED-конференций были выдающиеся личности, такие как математик Бенуа Мандельброт, теоретик искусственного интеллекта Марвин Минский, спортсменка Дана Ньяд и один из основателей Google Ларри Пейдж
#
# Однако история TED включает не только вдохновляющие, но и неоднозначные выступления. Так, в 2010 году Рэнди Пауэлл представил псевдонаучную концепцию «вихревой математики», вызвавшую споры. В 2014 году на конференции TEDMED выступила Элизабет Холмс, создательница ныне дискредитированного стартапа Theranos

# %% [markdown]
# ## Цель проекта

# %% [markdown]
# Создание интерактивных дашбордов и визуализаций для анализа выступлений на TED-конференциях с использованием Tableau, чтобы выявить ключевые тенденции, популярные тематики и характеристики авторов выступлений

# %% [markdown]
# ## Задачи проекта

# %% [markdown]
# 1) **Подготовка данных:**
# - Загрузить данные о выступлениях, конференциях и авторах.
# - Объединить файлы данных в единую таблицу.
# - Настроить связи между таблицами для формирования единой базы.
#
# 2) **Анализ данных:**
# - Изучить динамику количества конференций и выступлений по годам.
# - Определить год значительного роста популярности TED-конференций.
# - Проанализировать распределение выступлений по странам, годам и категориям.
# - Исследовать продолжительность выступлений, количество просмотров и реакцию аудитории (аплодисменты, смех).
#
# 3) **Создание дашбордов:**
# - Разработать дашборд «История выступлений» с визуализациями по странам, годам и категориям.
# - Построить дашборд «Тематики выступлений» для анализа распределения популярных тематик и реакции аудитории.
# - Создать дашборд «Авторы выступлений» для исследования областей деятельности и частоты выступлений авторов.
# - Сформировать дашборд на свободную тему для ответа на дополнительные вопросы.
#
# 4) **Настройка интерактивности:**
# - Настроить фильтры и действия на дашбордах для взаимосвязанного анализа данных.
# - Добавить параметры управления для выбора ключевых категорий и областей деятельности.
#
# 5) **Презентация результатов:**
# - Создать презентацию из четырёх дашбордов в формате Story в Tableau.
# - Опубликовать презентацию на Tableau Public с доступом для широкой аудитории

# %% [markdown]
# **Инструменты:** <br>
# Проект выполнялся в Desctop Tableau 2022.1

# %% [markdown]
# ## Выполнение работы с ссылкой

# %% [markdown]
# Ссылка на дашборды с презентацией представлены по ссылке ниже:
#
# [Ссылка на дашборд История выступлений»](https://public.tableau.com/shared/8B42MR25W?:display_count=n&:origin=viz_share_link)
#
# [Ссылка на дашборд «Тематики выступлений»](https://public.tableau.com/shared/NTWTD7MKG?:display_count=n&:origin=viz_share_link)
#
# [Ссылка на дашборд «Авторы выступлений»](https://public.tableau.com/shared/7R7F6FR73?:display_count=n&:origin=viz_share_link)
#
# [Ссылка на дашборд на свободную тему](https://public.tableau.com/shared/N935ZB87T?:display_count=n&:origin=viz_share_link)
#
# [Ссылка на презентацию (тык на меня 😊)](https://public.tableau.com/shared/GRC2K3XW3?:display_count=n&:origin=viz_shahttps://public.tableau.com/shared/SGT4N7G8F?:display_count=n&:origin=viz_share_linkre_link)
