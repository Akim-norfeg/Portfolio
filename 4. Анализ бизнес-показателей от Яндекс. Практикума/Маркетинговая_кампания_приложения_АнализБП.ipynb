# %% [markdown]
# # Проект "Маркетинговая кампания приложения"
# ## Описание проекта
# Вы — маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Ваша задача — разобраться в причинах и помочь компании выйти в плюс. <br>
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:<br>
# - лог сервера с данными об их посещениях,<br>
# - выгрузка их покупок за этот период,<br>
# - рекламные расходы.<br>
# Вам предстоит изучить:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.
#
# ## Описание данных
# В вашем распоряжении три датасета. Файл **visits_info_short.csv** хранит лог сервера с информацией о посещениях сайта, **orders_info_short.csv** — информацию о заказах, а **costs_info_short.csv** — информацию о расходах на рекламу <br><br>
# Структура **visits_info_short.csv**: <br>
# **User Id** — уникальный идентификатор пользователя,<br>
# **Region** — страна пользователя, <br>
# **Device** — тип устройства пользователя,<br>
# **Channel** — идентификатор источника перехода,<br>
# **Session Start** — дата и время начала сессии,<br>
# **Session End** — дата и время окончания сессии.<br><br>
# Структура **orders_info_short.csv**:<br>
# **User Id** — уникальный идентификатор пользователя,<br>
# **Event Dt** — дата и время покупки,<br>
# **Revenue** — сумма заказа.<br><br>
# Структура **costs_info_short.csv**:<br>
# **dt** — дата проведения рекламной кампании,<br>
# **Channel** — идентификатор рекламного источника,<br>
# **costs** — расходы на эту кампанию.<br>
#
# ## Обозначим шаги выполнения проекта:
#
# ### Шаг 1. Загрузите данные и подготовьте их к анализу
# - Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные. <br>
# - Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем
#
# ### Шаг 2. Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках
#
# ### Шаг 3. Исследовательский анализ данных
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
# - После каждого пункта сформулируйте выводы.
#
# ### Шаг 4. Маркетинг
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
# - Напишите промежуточные выводы.
#
# ### Шаг 5. Оцените окупаемость рекламы
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# <br><br> Ответьте на такие вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости?
# - Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.
#
# ### Шаг 6. Напишите выводы
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %%
import pandas as pd #импортируем библиотеки
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %% [markdown]
# ## Шаг 1. Загрузите данные и подготовьте их к анализу

# %%
try:
    visits, orders, costs = (
    pd.read_csv('/datasets/visits_info_short.csv'),  # визиты
    pd.read_csv('/datasets/orders_info_short.csv'),  # заказы
    pd.read_csv('/datasets/costs_info_short.csv'))  # расходы
except:
    visits, orders, costs = (
    pd.read_csv('visits_info_short.csv'),  # визиты
    pd.read_csv('orders_info_short.csv'),  # заказы
    pd.read_csv('costs_info_short.csv'),  # расходы
)

# %% [markdown]
# *Выведем в каждом датасете по 5 первых строк*

# %%
display(visits.head())
display(orders.head())
costs.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# ### Начнём Предобработку данных с датафрейма о визитах (**visits**)

# %% [markdown]
# *Напишем и применим функцию, которая улучшает столбцы датафреймов (пишет названия столбцов с маленькой буквы и заменяет пробел на нижнее подчеркивание)*

# %%
def update_in_columns(df):
    df.columns = df.columns.str.replace(' ', '_')
    df.columns = df.columns.str.lower()
    return df
visits = update_in_columns(visits)
orders = update_in_columns(orders)
costs = update_in_columns(costs)

visits.head()
# Out:
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
# получим общую информацию о датафрейме
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# **Получив общую информацию о датасете, видим, что не все столбцы имеют необходимый тип данных (столбцы с датой начала и конца сессии), отсутствуют пропуски в данных. Необходимо рассмотреть явные и неявные дубликаты, изменить данных внутри датафрейма** <br>
# *(Вперёд и с песней)*

# %%
visits.duplicated().sum() #явные дубликаты отсутствуют
# Out:
# 0

# %%
visits['region'].unique() #в столбце с названием регионов всё хорошо, нет необходимости приводить к строчным буквам и удалять пробелы, к тому же в других таблицах похожего столбца нет
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits['device'].unique() #в столбце с названием девайсов всё хорошо, нет необходимости приводить к строчным буквам и удалять пробелы, к тому же в других таблицах похожего столбца нет
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['channel'].unique() #в столбце с названием каналов всё хорошо, нет необходимости приводить к строчным буквам и удалять пробелы, к тому же в других таблицах похожего столбца нет
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
def function_to_date(date): #напишем функцию, которая будет менять тип данных на дататайм
    return pd.to_datetime(date)
    
visits['session_start'] = function_to_date(visits['session_start'])
visits['session_end'] = function_to_date(visits['session_end'])
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %% [markdown]
# #### Была выполнена Предобработка данных датафрейма **visits**. Переписаны названия столбцов с маленькой буквы, заполнены пробелы нижними подчеркиваниями во всех трёх датафреймах, проверены дубликаты, переведены столбцы с началом и концом сессии к типу даты и времени

# %% [markdown]
# ### Выполним Предобработку данных датафрейма о заказах (**orders**)

# %%
orders.head()
# Out:
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
orders['event_dt'] = function_to_date(orders['event_dt']) #переведен столбец с датой и временем покупки к типу дататайм
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
orders.duplicated().sum() #проверены дубликаты
# Out:
# 0

# %% [markdown]
# #### Была выполнена Предобработка данных датафрейма **orders**. Проверены дубликаты, переведен столбец с датой и временем покупки к типу дататайм

# %% [markdown]
# ### Выполним Предобработку данных датафрейма с информацией о расходах на рекламу (**costs**)

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs.head()
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date  #переведен столбец с датой проведения рекламной компании к типу дататайм
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %%
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Проверены оба столбца с уникальными названиями каналов в датафреймах **costs** и **visits**. Они полностью совпадают, всё хорошо

# %%
costs.duplicated().sum() #дубликатов нет
# Out:
# 0

# %% [markdown]
# #### Была выполнена Предобработка данных датафрейма **costs**. Проверены дубликаты, переведен столбец с датой проведения рекламной компании к типу дататайм, сравнены  уникальные названиям каналов в датафреймах **costs** и **visits**. Они полностью совпадают, всё хорошо

# %% [markdown]
# ### Выводы "Шаг №1. Загрузите данные и подготовьте их к анализу"
# - Были загружены данные из трёх датафреймов и подготовлены к анализу
# - Была выполнена Предобработка данных датафрейма **visits**. Переписаны названия столбцов с маленькой буквы, заполнены пробелы нижними подчеркиваниями во всех трёх датафреймах, проверены дубликаты, переведены столбцы с началом и концом сессии к типу даты и времени
# - Была выполнена Предобработка данных датафрейма **orders**. Проверены дубликаты, переведен столбец с датой и временем покупки к типу дататайм
# - Была выполнена Предобработка данных датафрейма **costs**. Проверены дубликаты, переведен столбец с датой проведения рекламной компании к типу дататайм, сравнены  уникальные названиям каналов в датафреймах **costs** и **visits**. Они полностью совпадают

# %% [markdown]
# ## Шаг №2. Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии
#
# Функции для вычисления значений метрик:
# - **get_profiles()** — для создания профилей пользователей,<br>
# - **get_retention()** — для подсчёта Retention Rate,<br>
# - **get_conversion()** — для подсчёта конверсии,<br>
# - **get_ltv()** — для подсчёта LTV.<br>
#
#
# Функции для построения графиков:
# - **filter_data()** — для сглаживания данных,<br>
# - **plot_retention()** — для построения графика Retention Rate,<br>
# - **plot_conversion()** — для построения графика конверсии,<br>
# - **plot_ltv_roi** — для визуализации LTV и ROI

# %%
def get_profiles(visits, orders, costs):

    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = pd.to_datetime(profiles['first_ts']).dt.to_period('M').dt.to_timestamp()

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# *Загрузим функции для визуализации метрик*

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Выводы "Шаг №2. Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии"
# - Были заданы функции для расчёта и анализа LTV, ROI, удержания и конверсии: расчёт и визуализация датафреймов

# %% [markdown]
# ## Шаг №3. Исследовательский анализ данных

# %% [markdown]
# *Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей*

# %%
profiles = get_profiles(visits, orders, costs) #составили профили пользователей
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# *Установим момент и горизонт анализа, согласно условиям из 5 шага (я так понимаю, что он к третьему шагу тоже должен относиться)*

# %%
observation_date = datetime(2019, 11, 1).date() #момент анализа
display(observation_date)
horizon_days = 14 #горизонт анализа
# Out:
# datetime.date(2019, 11, 1)

# %%
min_analysis_date = profiles['first_ts'].min() #минимальная дата
min_analysis_date
# Out:
# Timestamp('2019-05-01 00:00:41')

# %% [markdown]
# *Рассчитаем максимальную дату как разницу между моментом анализа и горизонтом анализа. Так мы получим более правильную информацию о максимальной дате, чем если вызовем метод **max()***

# %%
max_analysis_date = profiles['first_ts'].max()
max_analysis_date
# Out:
# Timestamp('2019-10-27 23:59:04')

# %% [markdown]
# **Были составлены профили пользователей, определены минимальная и максимальная дата анализа, указан момент анализа 01.11.2019г. и горизонт анализа 14 дней. Минимальная дата соотвествует дате 01.05.2019г., а максимальная дата – 19.10.2019г.**

# %% [markdown]
# *Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу,
# отражающую количество пользователей и долю платящих из каждой страны*

# %%
group_of_payers_region = profiles.groupby('region').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
group_of_payers_region
# Out:
#               user_id payer
#               nunique   sum      mean
# region
# France          17450   663  0.037994
# Germany         14981   616  0.041119
# UK              17575   700  0.039829
# United States  100002  6902  0.069019

# %%
group_of_payers_region.columns = ['nunique_user_id', 'sum_payer', 'percent_payer'] #переименуем названия столбцов, чтобы можно было к ним обращаться
group_of_payers_region['percent_payer'] = group_of_payers_region['percent_payer'].apply(lambda x: format(x,'.2%')) #переведем долю платящих клиентов в проценты
group_of_payers_region = group_of_payers_region.sort_values(by='percent_payer', ascending=False) #отсортируем по убыванию доли платящих клиентов
group_of_payers_region
# Out:
#                nunique_user_id  sum_payer percent_payer
# region
# United States           100002       6902         6.90%
# Germany                  14981        616         4.11%
# UK                       17575        700         3.98%
# France                   17450        663         3.80%

# %% [markdown]
# **Сгрупировав таблицу с профилями пользователей по регионам, мы получили таблицу, в которой показывается количество уникальных пользователей, платящих клиентов и доля платящих клиентов в процентах. Проанализировав данную сгруппированную таблицу, можно увидеть, что пользователи приходят из таких стран, как *France, Germany, UK, United States*. БОльшая часть платящих клиентов приходится на страну *United States* с количеством, равным 6902 пользователя, а процентное соотношение равно 6.9%**

# %% [markdown]
# *Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства*

# %%
group_of_payers_device = profiles.groupby('device').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
group_of_payers_device
# Out:
#         user_id payer
#         nunique   sum      mean
# device
# Android   35032  2050  0.058518
# Mac       30042  1912  0.063644
# PC        30455  1537  0.050468
# iPhone    54479  3382  0.062079

# %%
group_of_payers_device.columns = ['nunique_user_id', 'sum_payer', 'percent_payer'] #переименуем названия столбцов, чтобы можно было к ним обращаться
group_of_payers_device['percent_payer'] = group_of_payers_device['percent_payer'].apply(lambda x: format(x,'.2%')) #переведем долю платящих клиентов в проценты
group_of_payers_device = group_of_payers_device.sort_values(by='percent_payer', ascending=False) #отсортируем по убыванию доли платящих клиентов
group_of_payers_device
# Out:
#          nunique_user_id  sum_payer percent_payer
# device
# Mac                30042       1912         6.36%
# iPhone             54479       3382         6.21%
# Android            35032       2050         5.85%
# PC                 30455       1537         5.05%

# %% [markdown]
# **Сгрупировав таблицу с профилями пользователей по устройствам, мы получили таблицу, в которой показывается количество уникальных пользователей, платящих клиентов и доля платящих клиентов в процентах. Проанализировав данную сгруппированную таблицу, можно увидеть, что пользователи пользуются такими устройствами, как *Mac, iPhone, Android, PC*. БОльшая часть платящих клиентов пользуется устройством *Mac* с количеством, равным 1912 пользователя, а процентное соотношение равно 6.36%**

# %% [markdown]
# *Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения*

# %%
group_of_payers_channel = profiles.groupby('channel').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
group_of_payers_channel
# Out:
#                    user_id payer
#                    nunique   sum      mean
# channel
# AdNonSense            3880   440  0.113402
# FaceBoom             29144  3557  0.122049
# LeapBob               8553   262  0.030633
# MediaTornado          4364   156  0.035747
# OppleCreativeMedia    8605   233  0.027077
# RocketSuperAds        4448   352  0.079137
# TipTop               19561  1878  0.096007
# WahooNetBanner        8553   453  0.052964
# YRabbit               4312   165  0.038265
# lambdaMediaAds        2149   225  0.104700
# organic              56439  1160  0.020553

# %%
group_of_payers_channel.columns = ['nunique_user_id', 'sum_payer', 'percent_payer'] #переименуем названия столбцов, чтобы можно было к ним обращаться
group_of_payers_channel['percent_payer'] = group_of_payers_channel['percent_payer'].apply(lambda x: format(x,'.2%')) #переведем долю платящих клиентов в проценты
group_of_payers_channel = group_of_payers_channel.sort_values(by='percent_payer', ascending=False) #отсортируем по убыванию доли платящих клиентов
group_of_payers_channel
# Out:
#                     nunique_user_id  sum_payer percent_payer
# channel
# TipTop                        19561       1878         9.60%
# RocketSuperAds                 4448        352         7.91%
# WahooNetBanner                 8553        453         5.30%
# YRabbit                        4312        165         3.83%
# MediaTornado                   4364        156         3.57%
# LeapBob                        8553        262         3.06%
# OppleCreativeMedia             8605        233         2.71%
# organic                       56439       1160         2.06%
# FaceBoom                      29144       3557        12.20%
# AdNonSense                     3880        440        11.34%
# lambdaMediaAds                 2149        225        10.47%

# %%
profiles['channel'].unique()
# Out:
# array(['FaceBoom', 'organic', 'AdNonSense', 'YRabbit', 'MediaTornado',
#        'RocketSuperAds', 'LeapBob', 'TipTop', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# **Сгрупировав таблицу с профилями пользователей по каналам привлечения рекламы, мы получили таблицу, в которой показывается количество уникальных пользователей, платящих клиентов и доля платящих клиентов в процентах. Проанализировав данную сгруппированную таблицу, можно увидеть, что пользователи переходят из таких каналов, как *'FaceBoom', 'organic', 'AdNonSense', 'YRabbit', 'MediaTornado', 'RocketSuperAds', 'LeapBob', 'TipTop', WahooNetBanner', 'OppleCreativeMedia', 'lambdaMediaAds'*. БОльшая часть платящих клиентов переходит из канала *TipTop* с количеством, равным 1878 пользователя, а процентное соотношение равно 9.6%**

# %% [markdown]
# ### Вывод "Шаг №3. Исследовательский анализ данных"
# - Были составлены профили пользователей, определены минимальная и максимальная дата анализа, указан момент анализа 01.11.2019г. и горизонт анализа 14 дней. Минимальная дата соотвествует дате 01.05.2019г., а максимальная дата – 19.10.2019г.
#
# - Сгрупировав таблицу с профилями пользователей по регионам, мы получили таблицу, в которой показывается количество уникальных пользователей, платящих клиентов и доля платящих клиентов в процентах. Проанализировав данную сгруппированную таблицу, можно увидеть, что пользователи приходят из таких стран, как *France, Germany, UK, United States*. БОльшая часть платящих клиентов приходится на страну *United States* с количеством, равным 6902 пользователя, а процентное соотношение равно 6.9%
#
# - Сгрупировав таблицу с профилями пользователей по устройствам, мы получили таблицу, в которой показывается количество уникальных пользователей, платящих клиентов и доля платящих клиентов в процентах. Проанализировав данную сгруппированную таблицу, можно увидеть, что пользователи пользуются такими устройствами, как *Mac, iPhone, Android, PC*. БОльшая часть платящих клиентов пользуется устройством *Mac* с количеством, равным 1912 пользователя, а процентное соотношение равно 6.36%
#
# - Сгрупировав таблицу с профилями пользователей по каналам привлечения рекламы, мы получили таблицу, в которой показывается количество уникальных пользователей, платящих клиентов и доля платящих клиентов в процентах. Проанализировав данную сгруппированную таблицу, можно увидеть, что пользователи переходят из таких каналов, как *'FaceBoom', 'organic', 'AdNonSense', 'YRabbit', 'MediaTornado', 'RocketSuperAds', 'LeapBob', 'TipTop', WahooNetBanner', 'OppleCreativeMedia', 'lambdaMediaAds'*. БОльшая часть платящих клиентов переходит из канала *TipTop* с количеством, равным 1878 пользователя, а процентное соотношение равно 9.6%

# %% [markdown]
# ## Шаг №4. Маркетинг

# %%
costs.head()
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# *Посчитайте общую сумму расходов на маркетинг*

# %%
sum_of_marketing = costs['costs'].sum().round(1) #посчитаем сумму и окргулим ее до первой цифры после запятой
sum_of_marketing
# Out:
# 105497.3

# %% [markdown]
# **Общая сумма расходов на маркетинг составляет *105497.3***

# %% [markdown]
# *Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник*

# %%
costs_marketing_channel = pd.pivot_table(costs, index='channel', values='costs', aggfunc='sum').sort_values(by='costs', ascending=False)
costs_marketing_channel
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# **С помощью метода *pivot_table* был создан датфрейм, который показал, как траты распределены по рекламным источникам. Таким образом, больше всего денежных средств было потрачено на *TipTop – 54751.3, FaceBoom – 32445.6, WahooNetBanner – 5151***

# %% [markdown]
# *Постройте график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику*

# %% [markdown]
# *Для начала извлечем из даты столбца **costs** месяц и неделю*

# %%
costs['dt'] = pd.to_datetime(costs['dt']) #переведем в тип дататайм
costs['month'] = costs['dt'].dt.month #выделим номер месяца и добавим это в отедльный столбец
costs['week'] = costs['dt'].dt.isocalendar().week #выделим номер недели и добавим это в отедльный столбец
costs.head()
# Out:
#           dt   channel  costs  month  week
# 0 2019-05-01  FaceBoom  113.3      5    18
# 1 2019-05-02  FaceBoom   78.1      5    18
# 2 2019-05-03  FaceBoom   85.8      5    18
# 3 2019-05-04  FaceBoom  136.4      5    18
# 4 2019-05-05  FaceBoom  122.1      5    18

# %%
graf_week = pd.pivot_table(costs, index='week', columns='channel', values='costs', aggfunc='sum') #создаём сводную таблицу для графика
graf_week
# Out:
# channel  AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# week
# 18           211.05     535.7    16.80         38.64               24.00
# 19           273.00     750.2    31.71         61.68               34.50
# 20           265.65     755.7    26.67         59.04               27.50
# 21           266.70     722.7    26.67         50.16               34.25
# 22           202.65    1208.9    65.52         36.96               81.75
# 23           102.90    1081.3    66.99         27.60               79.50
# 24            96.60    1042.8    52.29         29.76               71.50
# 25           141.75    1280.4    68.46         32.16               79.75
# 26           148.05    1647.8    99.75         40.56              107.00
# 27           130.20    1536.7    87.36         43.44              102.50
# 28           106.05    1124.2    62.58         28.80               81.00
# 29            97.65     975.7    61.11         26.40               68.00
# ...

# %%
graf_week.plot(   #делаем график
    xlabel='Номер недели',
    ylabel='Стоимость рекламы в канале',
    title='Расходы на рекламу в зависимости от недели и канала',
    figsize=(15,10),
    grid=True)
plt.show()

# %% [markdown]
# *Заметно, что доминирующими по затратам на рекламу являются компании **TipTop** и **FaceBoom**, из-за чего нельзя хорошо рассмотреть графики других компаний. Для того, чтобы более детальнее выглядил график, уберем из анализа эти две доминирующие компании*

# %%
for_new_graf = costs.query('channel != "TipTop" & channel != "FaceBoom"')
graf_week_new = pd.pivot_table(for_new_graf, index='week', columns='channel', values='costs', aggfunc='sum') #создаём новую сводную таблицу для графика
graf_week_new.head()
# Out:
# channel  AdNonSense  LeapBob  MediaTornado  OppleCreativeMedia  \
# week
# 18           211.05    16.80         38.64               24.00
# 19           273.00    31.71         61.68               34.50
# 20           265.65    26.67         59.04               27.50
# 21           266.70    26.67         50.16               34.25
# 22           202.65    65.52         36.96               81.75
#
# channel  RocketSuperAds  WahooNetBanner  YRabbit  lambdaMediaAds
# week
# 18               99.450            49.2     52.2            81.6
# 19              139.230            92.4     75.9           103.2
# 20              138.060            90.0     69.3            90.4
# 21              131.040            79.2     65.4           119.2
# 22               97.695           179.4     49.8            83.2

# %%
graf_week_new.plot(   #делаем график без двух каналов
    xlabel='Номер недели',
    ylabel='Стоимость рекламы в канале',
    title='Расходы на рекламу в зависимости от недели и канала без каналов TipTop и FaceBoom',
    figsize=(15,10),
    grid=True)
plt.show()

# %% [markdown]
# *Теперь рассмотрим динамику расходов на рекламу по разным каналам по месяцам*

# %%
graf_month = pd.pivot_table(costs, index='month', columns='channel', values='costs', aggfunc='sum') #создаём сводную таблицу для графика
graf_month
# Out:
# channel  AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# month
# 5           1169.70    3524.4   140.28        238.56              169.75
# 6            538.65    5501.1   314.58        138.00              370.00
# 7            504.00    5294.3   313.53        138.48              366.50
# 8            579.60    6274.4   369.81        154.56              439.25
# 9            581.70    6114.9   343.98        144.72              427.75
# 10           537.60    5736.5   315.42        140.16              378.00
#
# channel  RocketSuperAds   TipTop  WahooNetBanner  YRabbit  lambdaMediaAds
# month
# 5               577.980   2981.0           418.8   299.70           458.4
# 6               325.715   6675.6           921.0   106.20           199.2
# 7               252.070   8410.2           851.4    97.38           219.2
# 8               253.110  11202.0          1040.4   124.74           220.0
# ...

# %%
graf_month.plot(   #делаем график
    xlabel='Номер месяца',
    ylabel='Стоимость рекламы в канале',
    title='Расходы на рекламу в зависимости от месяца и канала',
    figsize=(15,10),
    grid=True)
plt.show()

# %% [markdown]
# *Аналогично с графиками по неделям видим, что присутствуют те же самые две доминирующие каналы. Исключим их из анализа для бОльшей наглядности других каналов*

# %%
graf_month_new = pd.pivot_table(for_new_graf, index='month', columns='channel', values='costs', aggfunc='sum') #создаём новую сводную таблицу для графика
graf_month_new.plot(   #делаем график без двух каналов
    xlabel='Номер месяца',
    ylabel='Стоимость рекламы в канале',
    title='Расходы на рекламу в зависимости от месяца и канала без каналов TipTop и FaceBoom',
    figsize=(15,10),
    grid=True)
plt.show()

# %%
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# *Для моей хотелки покажем два графика рядом с помощью метода subplot – не зря же учили этому :)*

# %%
plt.figure(figsize = (18,5))

ax1=plt.subplot(1,2,1)
graf_month.plot(   #делаем график
    xlabel='Номер месяца',
    ylabel='Стоимость рекламы в канале',
    title='Расходы на рекламу в зависимости от месяца и канала',
    ax=ax1,
    grid=True)

ax2=plt.subplot(1,2,2)
graf_week.plot(   #делаем график
    xlabel='Номер недели',
    ylabel='Стоимость рекламы в канале',
    title='Расходы на рекламу в зависимости от недели и канала',
    ax=ax2,
    grid=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Код ревьюера
# costs['Расходы на привлечение по месяцам'] = costs['dt'].astype('datetime64[M]')
# costs['Расходы на привлечение по неделям'] = costs['dt'].astype('datetime64[W]')
#
# columns = ['Расходы на привлечение по месяцам', 'Расходы на привлечение по неделям']
#
# plt.subplots(figsize = (16, 5))
# for i, col in enumerate(columns):
#     costs.pivot_table(index = col, columns = 'channel', values = 'costs',
#                       aggfunc = 'sum').plot.area(ax = plt.subplot(1, 2, i + 1))
#     plt.title(col)
#     plt.xlabel('Дата')
#     plt.ylabel('Расходы, $')
#     plt.legend(ncol=3, bbox_to_anchor=(0, -0.4), loc='lower left', borderaxespad=0)
# plt.show()

# %%
plt.figure(figsize = (18,5))

ax1=plt.subplot(1,2,1)
graf_month_new.plot(   #делаем график без двух каналов
    xlabel='Номер месяца',
    ylabel='Стоимость рекламы в канале',
    title='Расходы на рекламу в зависимости от месяца и канала без каналов TipTop и FaceBoom',
    ax=ax1,
    grid=True)

ax2=plt.subplot(1,2,2)
graf_week_new.plot(   #делаем график без двух каналов
    xlabel='Номер недели',
    ylabel='Стоимость рекламы в канале',
    title='Расходы на рекламу в зависимости от недели и канала без каналов TipTop и FaceBoom',
    ax=ax2,
    grid=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Для построения графиков с визуализацией динамики изменения расходов во времени по неделям и месяцам по каждому источнику были созданы сводные таблицы из изначального датафрейма **costs**. Построив данные графики, сразу стали заметны два доминирующих канала по затрате на рекламу: *TipTop* и *FaceBoom*. Для того, чтобы более наглядно рассмотреть динамику других каналов, из сводных таблиц были исключены эти два доминирующих канала. Сравнивая графики, построенные по неделям и месяцам, по неделям позволяет более детально рассмотреть затраты каждого канала, график выглядит более волнистым, в то время как по месяцам – более пологим <br>
# Анализируя графики, исключающие две самые доминирующие каналы, можно заметить, что выделяются каналы "WahooNetBanner", "LeapBob", "OppleCreativeMedia", на которые относительно других не сокращаются расходы на рекламу, а в основном растут <br>
# Для удобства графики были расположены рядом с друг другом для бОльшей наглядности**

# %% [markdown]
# *Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей*

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['channel'])

# %%
max_date = ltv_raw['dt'].max()
max_date
# Out:
# datetime.date(2019, 10, 19)

# %%
profiles['dt'].max()
# Out:
# datetime.date(2019, 10, 27)

# %% [markdown]
# Выше видно, что в сырых данных дата остались учитываться момент анализа и горизонт, а в **profiles** необходимо сделать срез тех данных, которые необходимы для дальнейшего анализа

# %%
ltv_profiles = profiles.query('dt <= @max_date') #выполнили то, что написано выше

# %%
cac_channel = ltv_profiles.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean').rename(columns={'acquisition_cost': 'cac_for_channel'}).sort_values(by='cac_for_channel', ascending=False).round(2)
cac_channel #создали сводную таблицу, переименовали столбец, в котором производились расчеты, отсортировали по убыванию "cac" и округлили значение до двух знаков после запятой
# Out:
#                     cac_for_channel
# channel
# TipTop                         2.76
# FaceBoom                       1.11
# AdNonSense                     1.01
# lambdaMediaAds                 0.73
# WahooNetBanner                 0.60
# RocketSuperAds                 0.42
# OppleCreativeMedia             0.25
# MediaTornado                   0.22
# YRabbit                        0.22
# LeapBob                        0.21
# organic                        0.00

# %% [markdown]
# Рассчитаем теперь средний **cac** общий, для всех каналов, а так же посмотрим, какой средний **cac** будет без учета органических пользователей (которые пришли не в результате рекламной кампании)

# %%
cac_all = ltv_profiles['acquisition_cost'].mean().round(3)
print('Средний общий cac для всех каналов (с учётом organic) составляет {}'.format(cac_all))

cac_all_new = ltv_profiles.query('channel != "organic"')
cac_all_new = cac_all_new['acquisition_cost'].mean().round(3)
print('Средний общий cac для всех каналов (без учётом organic) составляет {}'.format(cac_all_new))
# Out:
# Средний общий cac для всех каналов (с учётом organic) составляет 0.695
# Средний общий cac для всех каналов (без учётом organic) составляет 1.118

# %% [markdown]
# *Визуализируем значение CAC по источнику с помощью графика*

# %%
ltv_profiles.pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='mean').plot(
xlabel='Дата',
ylabel='Уровень CAC',
title='Значение CAC по источнику',
figsize=(20,10)
)
plt.show()

# %% [markdown]
# **Были рассчитаны суммы денег, в которые компании обходится каждый новый клиент (CAC) в разбивке по рекламным каналам привлечения, общий с учетом органических пользователей (которые пришли не в рамках рекламной кампании) и общий без учета органических пользователей. Анализируя все показатели, можно сделать вывод, что самая высокая стоимость нового клиента в канале *TipTop* = 2.76, что превышает почти в 1.5 раза последующие за ним (второй и третий) каналы *FaceBoom* = 1.11 и *AdNonSense* = 1.01 <br>
# Средний CAC по всем каналам с учетом органических пользователей равен 0.695, без учёта органических – 1.118. Сумма привлечения органических пользователей равна нулю, это объясняется тем, что компания не тратила деньги на привление данных пользователей. Такие пользователи сами находят компанию: пример такого привлечения – "сарафанное радио"**

# %% [markdown]
# ### Выводы "Шаг №4. Маркетинг"
# - Общая сумма расходов на маркетинг составляет 105497.3
# - С помощью метода pivot_table был создан датфрейм, который показал, как траты распределены по рекламным источникам. Таким образом, больше всего денежных средств было потрачено на TipTop – 54751.3, FaceBoom – 32445.6, WahooNetBanner – 5151
# - Для построения графиков с визуализацией динамики изменения расходов во времени по неделям и месяцам по каждому источнику были созданы сводные таблицы из изначального датафрейма costs. Построив данные графики, сразу стали заметны два доминирующих канала по затрате на рекламу: TipTop и FaceBoom. Для того, чтобы более наглядно рассмотреть динамику других каналов, из сводных таблиц были исключены эти два доминирующих канала. Сравнивая графики, построенные по неделям и месяцам, по неделям позволяет более детально рассмотреть затраты каждого канала, график выглядит более волнистым, в то время как по месяцам – более пологим. Анализируя графики, исключающие две самые доминирующие каналы, можно заметить, что выделяются каналы "WahooNetBanner", "LeapBob", "OppleCreativeMedia", на которые относительно других не сокращаются расходы на рекламу, а в основном растут. Для удобства графики были расположены рядом с друг другом для бОльшей наглядности

# %% [markdown]
# ## Шаг №5. Оцените окупаемость рекламы

# %% [markdown]
# *Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI*

# %% [markdown]
# *Прежде всего необходимо исключить из анализа органических пользователей для корректного отображения результата, так как на органических пользователей не тратится рекламный бюджет*

# %%
profiles = profiles.query('channel != "organic"')
profiles['channel'].unique() #проверка выполненного кода строчкой выше
# Out:
# array(['FaceBoom', 'AdNonSense', 'YRabbit', 'MediaTornado',
#        'RocketSuperAds', 'LeapBob', 'TipTop', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days) #рассчитаем LTV и ROI

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) #визуализируем LTV и ROI для последующего анализа

# %% [markdown]
# **Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI:** <br>
# 1. Анализируя график LTV, видно, что общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок, в среднем по всем клиентам стабильно растёт – так и должно быть в теории, значит, всё верно
# 2. Анализируя график CAC заметно, что показатель стабильно растёт, что заставляет на это обратить особое внимание. Возможно, проблема неокупаемости рекламы связана с рекламным бюджетом
# 3. Реклама не окупается – на это указывает показатель ROI, который достигает максимум примерно 80%, а динамика постпенно снижается <br>
# **Чтобы разобраться в причинах, пройдём по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения**

# %% [markdown]
# *Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам*

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(profiles, orders, observation_date, horizon_days) #рассчитаем конверсию
plot_conversion(conversion_grouped, conversion_history, horizon_days)  #визуализируем конверсию

# %% [markdown]
# **Анализируя построенный график визуализации конверсии, видно, что конверсия растёт – это означает, что доля новых покупателей растёт – данный момент является хорошим показателем для компании**

# %%
retention_raw, retention_grouped, retention_history = get_retention(profiles, visits, observation_date, horizon_days) #рассчитаем удержание пользователей
plot_retention(retention_grouped, retention_history, horizon_days) #визуализируем удержание пользователей

# %% [markdown]
# **Анализируя построенные графики удержания, можно заметить, что удержание платящих пользователей всё время падает. С неплатящими похожая ситуация, однако в их случае всё закономерно: неплатящих клиентов меньше удерживает компания, так как они не платят денежные средства за пользование. Удержание платящих клиентов выше удержания неплатящих**

# %% [markdown]
# *Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI*

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions) #рассчитаем LTV и ROI

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) #визуализируем LTV и ROI для последующего анализа

# %% [markdown]
# **Оценим окупаемость рекламы с разбивкой по устройствам: у всех устройств реклама не окупается кроме пользователей *PC* в последние дни лайфтайма. При этом Стоимость привлечения пользователей (CAC) стабильно растёт у всех устройств, однако пользователи *PC* растут менее сильно относительно своих "товарищей". Вполне вероятно, что из-за меньших расходов на рекламу у пользователей PC, окупаемость выросла сильнее. Необходимо сократить расходы на все устойства кроме PC (Mac, Android, iPhine), так как привлечение всё бОльших средств в привлечение пользователей не позволяет сказать об окупаемости**

# %% [markdown]
# *Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI*

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions) #рассчитаем LTV и ROI

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) #визуализируем LTV и ROI для последующего анализа

# %% [markdown]
# **Оценим окупаемость рекламы с разбивкой по странам: Окупаются все страны кроме *United States*. Так же заметно, что Динамика стоиомости привлечения пользователей (CAC) у этой страны сильно отличается от отсальных: растёт на их фоне. Иаким образом, из-за больших средств, потраченных на привлечение клиентов из США, окупаемости реклама в данной стране не достигла. Стоимость привлечения пользователей из стран помимо *United States* сократилась относительно изначального показателя и осталась стабильной спустя первый месяц, но при этом реклама в этих странах окупилась уже на 5 день. Необходимо сократить денежные средства, инвестируемые в рекламу для пользователей Соединенных Штатов и понаблюдать за состоянием – не исключено, что именно благодаря этому шагу окупаемость возрастет**

# %% [markdown]
# *Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI*

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions) #рассчитаем LTV и ROI

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) #визуализируем LTV и ROI для последующего анализа

# %% [markdown]
# **Оценим окупаемость рекламы с разбивкой по рекламным каналам привлечения клиентов: не окупаются три канала: *TipTop, AdNonSense и FaceBoom*. Заметим при этом, что Расходы на привлечение пользователей через канал *TipTop* сильно высокие, в то время как стоимость привлечения в других каналах всё время стабильна**

# %% [markdown]
# *После изучения и анализа графиков и расчетов заметно, что окупаются все страны кроме США, поэтому, возможно, есть необходимость рассмотреть каналы США и других стран отдельно*

# %%
profiles_USA = profiles.query('region == "United States"') #выполним срез для американских пользователей

dimensions = ['device'] #для устройств
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_USA, orders, observation_date, horizon_days, dimensions=dimensions) #рассчитаем LTV и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) #визуализируем LTV и ROI для последующего анализа

dimensions = ['channel'] #для рекламных каналов
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_USA, orders, observation_date, horizon_days, dimensions=dimensions) #рассчитаем LTV и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) #визуализируем LTV и ROI для последующего анализа

# %% [markdown]
# **Проведя срез для дополнительного изучения ситуации с девайсами и каналами из *США*, явно видно, что каналы *FaceBoom* и *TipTop*, имея большие рекламные расходы, не окупаются. Причем если CAC в *FaceBoom* стабильна, то в *TipTop* всё больше и больше денежных средств постпает для продвижения, однако это безуспешно, не даёт свои плоды расцветания в *США*. Если же рассматривать ситуацию с девайсами, то рекламный бюджет ни в одном из устройств не окупается. А постоянное привлечение новых денежных средств в рекламную кампанию хоть и стимулирует рост окупаемости, но достигает максимум примерно 75%. Так как не окупаются пользователи на всех девайсах и каналы *FaceBoom* и *TipTop*, то необходимо сократить рекламный бюджет на эти каналы и перенапривить на те каналы, которые выглядят более надежными по окупаемости и низким изначальным показателем CAC – это такие каналы, как *YRabbit, MediaTornado* и другие**

# %% [markdown]
# *Рассмотрим теперь ситуацию во всех странах кроме США*

# %%
profiles_not_USA = profiles.query('region != "United States"')

dimensions = ['device'] #для устройств
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_not_USA, orders, observation_date, horizon_days, dimensions=dimensions) #рассчитаем LTV и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) #визуализируем LTV и ROI для последующего анализа

dimensions = ['channel'] #для рекламных каналов
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_not_USA, orders, observation_date, horizon_days, dimensions=dimensions) #рассчитаем LTV и ROI
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days) #визуализируем LTV и ROI для последующего анализа

# %% [markdown]
# **Проведя срез для дополнительного изучения ситуации с девайсами и каналами не из *США*, можно сразу сказать, что ситуация гораздо лучше, чем в *"USA"*: все девайсы окупились уже на 6 день лайфтайма, учитывая что CAC сократилась через месяц, а затем стабилизировалась – это отличный показатель; а, анализируя рекламные каналы, можно сказать, что не окупился только *AdNonSense*. Пусть на него и было потрачено больше средств относительно других каналов не из *Америки*, но при этом CAC была стабильной, и канал окупиться не смог. Интересный факт, но вновь такая взаимосвязь, что канал AdNonSense, на который больше относительно других каналов был потрачены рекламный бюджет, не окупился, поэтому необходимо перенаправить денежные средства на более приоритетный к окупаемости канал *lambdaMediaAds***

# %% [markdown]
# *Теперь проведем аналогичный анализ конверсии и удержания по устройствам, странам и каналам*

# %% [markdown]
# - *Анализ конверсии и удержания по устройствам*

# %%
dimensions = ['device'] #разбивка по устройствам
conversion_raw, conversion_grouped, conversion_history = get_conversion(     #создание расчетной таблицы для конверсии пользователей
    profiles, orders, observation_date, horizon_days, dimensions=dimensions)
plot_conversion(conversion_grouped, conversion_history, horizon_days) #визуализация конверсии


dimensions = ['device'] #разбивка по устройствам
retention_raw, retention_grouped, retention_history = get_retention(     #создание расчетной таблицы для конверсии пользователей
    profiles, visits, observation_date, horizon_days, dimensions=dimensions)
plot_retention(retention_grouped, retention_history, horizon_days)     #визуализация конверсии

# %% [markdown]
# **Конверсия пользователей с устройствами *Mac* выше относительно других, однако, учитывая самую низкую конверсию у *PC*, показатель Удержания платящих пользователей выше других. Важно так же заметить, что динамика конверсии пользователей *PC* в некоторые дни сильно "проседает". Необходимо больше вкладываться в рекламу для пользователей PC, тогда они будут приность бОльшую прибыль, а расходы на пользователей Mac сократить**

# %% [markdown]
# - *Анализ конверсии и удержания по странам*

# %%
dimensions = ['region'] #разбивка по устройствам
conversion_raw, conversion_grouped, conversion_history = get_conversion(     #создание расчетной таблицы для конверсии пользователей
    profiles, orders, observation_date, horizon_days, dimensions=dimensions)
plot_conversion(conversion_grouped, conversion_history, horizon_days) #визуализация конверсии


dimensions = ['region'] #разбивка по устройствам
retention_raw, retention_grouped, retention_history = get_retention(     #создание расчетной таблицы для конверсии пользователей
    profiles, visits, observation_date, horizon_days, dimensions=dimensions)
plot_retention(retention_grouped, retention_history, horizon_days)     #визуализация конверсии

# %% [markdown]
# **Конверсия пользователей в Соединенных Штатах демонстрируют более высокие показатели по сравнению с другими регионами (почти в два раза), причем удержание платящих пользователей самое низкое в этом регионе. Необходимо всё же сократить расходы на пользователей из страны USA**

# %% [markdown]
# - *Анализ конверсии и удержания по каналам*

# %%
dimensions = ['channel'] #разбивка по каналам
conversion_raw, conversion_grouped, conversion_history = get_conversion(     #создание расчетной таблицы для конверсии пользователей
    profiles, orders, observation_date, horizon_days, dimensions=dimensions)
plot_conversion(conversion_grouped, conversion_history, horizon_days) #визуализация конверсии


dimensions = ['channel'] #разбивка по каналам
retention_raw, retention_grouped, retention_history = get_retention(     #создание расчетной таблицы для конверсии пользователей
    profiles, visits, observation_date, horizon_days, dimensions=dimensions)
plot_retention(retention_grouped, retention_history, horizon_days)     #визуализация конверсии

# %% [markdown]
# **Рассматривая пользователей из разных каналов, можно сделать вывод, что ТОП-3 по показателям конверсии являются каналы *"FaceBoom", "AdNonSense" и "lambdaMedianAds"*, но в то же время самым низким удержанием (почти в два раз ниже остальных) обладают каналы *"FaceBoom" и "AdNonSense"*. Графики выше вновь подтверждают необходимость сокращения рекламного бюджета на каналы *FaceBoom и AdNonSense*. Стоит приглядеться к фирме *WahooNetBanner*, так как пользователи там удерживаются почти лучше всех относительно остальных при том, что показатель CAC этого канала не самый высокий в сравнении с другими каналами**

# %% [markdown]
# **Ответы на вопросы: "Окупается ли реклама, направленная на привлечение пользователей в целом? Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы? Чем могут быть вызваны проблемы окупаемости?" были написаны в ходе работы, а так же были даны промежуточные рекомендации для рекламного отдела в процессе каждого отдельного анализа работы**

# %% [markdown]
# ### Выводы "Шаг №5.  Оцените окупаемость рекламы"
# - Прежде всего необходимо исключить из анализа органических пользователей для корректного отображения результата, так как на органических пользователей не тратится рекламный бюджет
# - Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI: <br>
# 1. Анализируя график LTV, видно, что общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок, в среднем по всем клиентам стабильно растёт – так и должно быть в теории, значит, всё верно
# 2. Анализируя график CAC заметно, что показатель стабильно растёт, что заставляет на это обратить особое внимание. Возможно, проблема неокупаемости рекламы связана с рекламным бюджетом
# 3. Реклама не окупается – на это указывает показатель ROI, который достигает максимум примерно 80%, а динамика постпенно снижается <br>
# Чтобы разобраться в причинах, пройдём по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения
#
# - Анализируя построенный график визуализации конверсии, видно, что конверсия растёт – это означает, что доля новых покупателей растёт – данный момент является хорошим показателем для компании
#
# - Анализируя построенные графики удержания, можно заметить, что удержание платящих пользователей всё время падает. С неплатящими похожая ситуация, однако в их случае всё закономерно: неплатящих клиентов меньше удерживает компания, так как они не платят денежные средства за пользование. Удержание платящих клиентов выше удержания неплатящих
#
# - Оценим окупаемость рекламы с разбивкой по устройствам: у всех устройств реклама не окупается кроме пользователей *PC* в последние дни лайфтайма. При этом Стоимость привлечения пользователей (CAC) стабильно растёт у всех устройств, однако пользователи *PC* растут менее сильно относительно своих "товарищей". Вполне вероятно, что из-за меньших расходов на рекламу у пользователей PC, окупаемость выросла сильнее. Необходимо сократить расходы на все устойства кроме PC (Mac, Android, iPhine), так как привлечение всё бОльших средств в привлечение пользователей не позволяет сказать об окупаемости
#
# - Оценим окупаемость рекламы с разбивкой по странам: Окупаются все страны кроме *United States*. Так же заметно, что Динамика стоиомости привлечения пользователей (CAC) у этой страны сильно отличается от отсальных: растёт на их фоне. Иаким образом, из-за больших средств, потраченных на привлечение клиентов из США, окупаемости реклама в данной стране не достигла. Стоимость привлечения пользователей из стран помимо *United States* сократилась относительно изначального показателя и осталась стабильной спустя первый месяц, но при этом реклама в этих странах окупилась уже на 5 день. Необходимо сократить денежные средства, инвестируемые в рекламу для пользователей Соединенных Штатов и понаблюдать за состоянием – не исключено, что именно благодаря этому шагу окупаемость возрастет
#
# - Оценим окупаемость рекламы с разбивкой по рекламным каналам привлечения клиентов: не окупаются три канала: *TipTop, AdNonSense и FaceBoom*. Заметим при этом, что Расходы на привлечение пользователей через канал *TipTop* сильно высокие, в то время как стоимость привлечения в других каналах всё время стабильна
#
# - Проведя срез для дополнительного изучения ситуации с девайсами и каналами из *США*, явно видно, что каналы *FaceBoom* и *TipTop*, имея большие рекламные расходы, не окупаются. Причем если CAC в *FaceBoom* стабильна, то в *TipTop* всё больше и больше денежных средств постпает для продвижения, однако это безуспешно, не даёт свои плоды расцветания в *США*. Если же рассматривать ситуацию с девайсами, то рекламный бюджет ни в одном из устройств не окупается. А постоянное привлечение новых денежных средств в рекламную кампанию хоть и стимулирует рост окупаемости, но достигает максимум примерно 75%. Так как не окупаются пользователи на всех девайсах и каналы *FaceBoom* и *TipTop*, то необходимо сократить рекламный бюджет на эти каналы и перенапривить на те каналы, которые выглядят более надежными по окупаемости и низким изначальным показателем CAC – это такие каналы, как *YRabbit, MediaTornado* и другие
#
# - Проведя срез для дополнительного изучения ситуации с девайсами и каналами не из *США*, можно сразу сказать, что ситуация гораздо лучше, чем в *"USA"*: все девайсы окупились уже на 6 день лайфтайма, учитывая что CAC сократилась через месяц, а затем стабилизировалась – это отличный показатель; а, анализируя рекламные каналы, можно сказать, что не окупился только *AdNonSense*. Пусть на него и было потрачено больше средств относительно других каналов не из *Америки*, но при этом CAC была стабильной, и канал окупиться не смог. Интересный факт, но вновь такая взаимосвязь, что канал AdNonSense, на который больше относительно других каналов был потрачены рекламный бюджет, не окупился, поэтому необходимо перенаправить денежные средства на более приоритетный к окупаемости канал *lambdaMediaAds*
#
# - Конверсия пользователей с устройствами *Mac* выше относительно других, однако, учитывая самую низкую конверсию у *PC*, показатель Удержания платящих пользователей выше других. Важно так же заметить, что динамика конверсии пользователей *PC* в некоторые дни сильно "проседает". Необходимо больше вкладываться в рекламу для пользователей PC, тогда они будут приность бОльшую прибыль, а расходы на пользователей Mac сократить
#
# - Конверсия пользователей в Соединенных Штатах демонстрируют более высокие показатели по сравнению с другими регионами (почти в два раза), причем удержание платящих пользователей самое низкое в этом регионе. Необходимо всё же сократить расходы на пользователей из страны USA
#
# - Рассматривая пользователей из разных каналов, можно сделать вывод, что ТОП-3 по показателям конверсии являются каналы *"FaceBoom", "AdNonSense" и "lambdaMedianAds"*, но в то же время самым низким удержанием (почти в два раз ниже остальных) обладают каналы *"FaceBoom" и "AdNonSense"*. Графики выше вновь подтверждают необходимость сокращения рекламного бюджета на каналы *FaceBoom и AdNonSense*. Стоит приглядеться к фирме *WahooNetBanner*, так как пользователи там удерживаются почти лучше всех относительно остальных при том, что показатель CAC этого канала не самый высокий в сравнении с другими каналами

# %% [markdown]
# # Выводы по Проекту "Анализ бизнес-показателей"
#
# ### Выводы "Шаг №1. Загрузите данные и подготовьте их к анализу"
# - Были загружены данные из трёх датафреймов и подготовлены к анализу
# - Была выполнена Предобработка данных датафрейма **visits**. Переписаны названия столбцов с маленькой буквы, заполнены пробелы нижними подчеркиваниями во всех трёх датафреймах, проверены дубликаты, переведены столбцы с началом и концом сессии к типу даты и времени
# - Была выполнена Предобработка данных датафрейма **orders**. Проверены дубликаты, переведен столбец с датой и временем покупки к типу дататайм
# - Была выполнена Предобработка данных датафрейма **costs**. Проверены дубликаты, переведен столбец с датой проведения рекламной компании к типу дататайм, сравнены  уникальные названиям каналов в датафреймах **costs** и **visits**. Они полностью совпадают
#
# ### Выводы "Шаг №2. Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии"
# - Были заданы функции для расчёта и анализа LTV, ROI, удержания и конверсии: расчёт и визуализация датафреймов
#
# ### Вывод "Шаг №3. Исследовательский анализ данных"
# - Были составлены профили пользователей, определены минимальная и максимальная дата анализа, указан момент анализа 01.11.2019г. и горизонт анализа 14 дней. Минимальная дата соотвествует дате 01.05.2019г., а максимальная дата – 19.10.2019г.
#
# - Сгрупировав таблицу с профилями пользователей по регионам, мы получили таблицу, в которой показывается количество уникальных пользователей, платящих клиентов и доля платящих клиентов в процентах. Проанализировав данную сгруппированную таблицу, можно увидеть, что пользователи приходят из таких стран, как *France, Germany, UK, United States*. БОльшая часть платящих клиентов приходится на страну *United States* с количеством, равным 6902 пользователя, а процентное соотношение равно 6.9%
#
# - Сгрупировав таблицу с профилями пользователей по устройствам, мы получили таблицу, в которой показывается количество уникальных пользователей, платящих клиентов и доля платящих клиентов в процентах. Проанализировав данную сгруппированную таблицу, можно увидеть, что пользователи пользуются такими устройствами, как *Mac, iPhone, Android, PC*. БОльшая часть платящих клиентов пользуется устройством *Mac* с количеством, равным 1912 пользователя, а процентное соотношение равно 6.36%
#
# - Сгрупировав таблицу с профилями пользователей по каналам привлечения рекламы, мы получили таблицу, в которой показывается количество уникальных пользователей, платящих клиентов и доля платящих клиентов в процентах. Проанализировав данную сгруппированную таблицу, можно увидеть, что пользователи переходят из таких каналов, как *'FaceBoom', 'organic', 'AdNonSense', 'YRabbit', 'MediaTornado', 'RocketSuperAds', 'LeapBob', 'TipTop', WahooNetBanner', 'OppleCreativeMedia', 'lambdaMediaAds'*. БОльшая часть платящих клиентов переходит из канала *TipTop* с количеством, равным 1878 пользователя, а процентное соотношение равно 9.6%
#
# ### Выводы "Шаг №4. Маркетинг"
# - Общая сумма расходов на маркетинг составляет 105497.3
# - С помощью метода pivot_table был создан датфрейм, который показал, как траты распределены по рекламным источникам. Таким образом, больше всего денежных средств было потрачено на TipTop – 54751.3, FaceBoom – 32445.6, WahooNetBanner – 5151
# - Для построения графиков с визуализацией динамики изменения расходов во времени по неделям и месяцам по каждому источнику были созданы сводные таблицы из изначального датафрейма costs. Построив данные графики, сразу стали заметны два доминирующих канала по затрате на рекламу: TipTop и FaceBoom. Для того, чтобы более наглядно рассмотреть динамику других каналов, из сводных таблиц были исключены эти два доминирующих канала. Сравнивая графики, построенные по неделям и месяцам, по неделям позволяет более детально рассмотреть затраты каждого канала, график выглядит более волнистым, в то время как по месяцам – более пологим. Анализируя графики, исключающие две самые доминирующие каналы, можно заметить, что выделяются каналы "WahooNetBanner", "LeapBob", "OppleCreativeMedia", на которые относительно других не сокращаются расходы на рекламу, а в основном растут. Для удобства графики были расположены рядом с друг другом для бОльшей наглядности
#
# ### Выводы "Шаг №5.  Оцените окупаемость рекламы"
# - Прежде всего необходимо исключить из анализа органических пользователей для корректного отображения результата, так как на органических пользователей не тратится рекламный бюджет
# - Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI: <br>
# 1. Анализируя график LTV, видно, что общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок, в среднем по всем клиентам стабильно растёт – так и должно быть в теории, значит, всё верно
# 2. Анализируя график CAC заметно, что показатель стабильно растёт, что заставляет на это обратить особое внимание. Возможно, проблема неокупаемости рекламы связана с рекламным бюджетом
# 3. Реклама не окупается – на это указывает показатель ROI, который достигает максимум примерно 80%, а динамика постпенно снижается <br>
# Чтобы разобраться в причинах, пройдём по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения
#
# - Анализируя построенный график визуализации конверсии, видно, что конверсия растёт – это означает, что доля новых покупателей растёт – данный момент является хорошим показателем для компании
#
# - Анализируя построенные графики удержания, можно заметить, что удержание платящих пользователей всё время падает. С неплатящими похожая ситуация, однако в их случае всё закономерно: неплатящих клиентов меньше удерживает компания, так как они не платят денежные средства за пользование. Удержание платящих клиентов выше удержания неплатящих
#
# - Оценим окупаемость рекламы с разбивкой по устройствам: у всех устройств реклама не окупается кроме пользователей *PC* в последние дни лайфтайма. При этом Стоимость привлечения пользователей (CAC) стабильно растёт у всех устройств, однако пользователи *PC* растут менее сильно относительно своих "товарищей". Вполне вероятно, что из-за меньших расходов на рекламу у пользователей PC, окупаемость выросла сильнее. Необходимо сократить расходы на все устойства кроме PC (Mac, Android, iPhine), так как привлечение всё бОльших средств в привлечение пользователей не позволяет сказать об окупаемости
#
# - Оценим окупаемость рекламы с разбивкой по странам: Окупаются все страны кроме *United States*. Так же заметно, что Динамика стоиомости привлечения пользователей (CAC) у этой страны сильно отличается от отсальных: растёт на их фоне. Иаким образом, из-за больших средств, потраченных на привлечение клиентов из США, окупаемости реклама в данной стране не достигла. Стоимость привлечения пользователей из стран помимо *United States* сократилась относительно изначального показателя и осталась стабильной спустя первый месяц, но при этом реклама в этих странах окупилась уже на 5 день. Необходимо сократить денежные средства, инвестируемые в рекламу для пользователей Соединенных Штатов и понаблюдать за состоянием – не исключено, что именно благодаря этому шагу окупаемость возрастет
#
# - Оценим окупаемость рекламы с разбивкой по рекламным каналам привлечения клиентов: не окупаются три канала: *TipTop, AdNonSense и FaceBoom*. Заметим при этом, что Расходы на привлечение пользователей через канал *TipTop* сильно высокие, в то время как стоимость привлечения в других каналах всё время стабильна
#
# - Проведя срез для дополнительного изучения ситуации с девайсами и каналами из *США*, явно видно, что каналы *FaceBoom* и *TipTop*, имея большие рекламные расходы, не окупаются. Причем если CAC в *FaceBoom* стабильна, то в *TipTop* всё больше и больше денежных средств постпает для продвижения, однако это безуспешно, не даёт свои плоды расцветания в *США*. Если же рассматривать ситуацию с девайсами, то рекламный бюджет ни в одном из устройств не окупается. А постоянное привлечение новых денежных средств в рекламную кампанию хоть и стимулирует рост окупаемости, но достигает максимум примерно 75%. Так как не окупаются пользователи на всех девайсах и каналы *FaceBoom* и *TipTop*, то необходимо сократить рекламный бюджет на эти каналы и перенапривить на те каналы, которые выглядят более надежными по окупаемости и низким изначальным показателем CAC – это такие каналы, как *YRabbit, MediaTornado* и другие
#
# - Проведя срез для дополнительного изучения ситуации с девайсами и каналами не из *США*, можно сразу сказать, что ситуация гораздо лучше, чем в *"USA"*: все девайсы окупились уже на 6 день лайфтайма, учитывая что CAC сократилась через месяц, а затем стабилизировалась – это отличный показатель; а, анализируя рекламные каналы, можно сказать, что не окупился только *AdNonSense*. Пусть на него и было потрачено больше средств относительно других каналов не из *Америки*, но при этом CAC была стабильной, и канал окупиться не смог. Интересный факт, но вновь такая взаимосвязь, что канал AdNonSense, на который больше относительно других каналов был потрачены рекламный бюджет, не окупился, поэтому необходимо перенаправить денежные средства на более приоритетный к окупаемости канал *lambdaMediaAds*
#
# - Конверсия пользователей с устройствами *Mac* выше относительно других, однако, учитывая самую низкую конверсию у *PC*, показатель Удержания платящих пользователей выше других. Важно так же заметить, что динамика конверсии пользователей *PC* в некоторые дни сильно "проседает". Необходимо больше вкладываться в рекламу для пользователей PC, тогда они будут приность бОльшую прибыль, а расходы на пользователей Mac сократить
#
# - Конверсия пользователей в Соединенных Штатах демонстрируют более высокие показатели по сравнению с другими регионами (почти в два раза), причем удержание платящих пользователей самое низкое в этом регионе. Необходимо всё же сократить расходы на пользователей из страны USA
#
# - Рассматривая пользователей из разных каналов, можно сделать вывод, что ТОП-3 по показателям конверсии являются каналы *"FaceBoom", "AdNonSense" и "lambdaMedianAds"*, но в то же время самым низким удержанием (почти в два раз ниже остальных) обладают каналы *"FaceBoom" и "AdNonSense"*. Графики выше вновь подтверждают необходимость сокращения рекламного бюджета на каналы *FaceBoom и AdNonSense*. Стоит приглядеться к фирме *WahooNetBanner*, так как пользователи там удерживаются почти лучше всех относительно остальных при том, что показатель CAC этого канала не самый высокий в сравнении с другими каналам
